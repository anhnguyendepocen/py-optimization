# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Streaming-Data" data-toc-modified-id="Streaming-Data-1">Streaming Data</a></span></li></ul></div>

# %% [markdown]
# # Streaming Data

# %%
# import the tools
from optics_tools import *

# make sure you include this at the top of any code cell that runs the graphs:
# it tells the Jupyter Notebook to automatically show any graphs that we instantiate
# %matplotlib notebook

# in order to actually capture your data and be able to save it, you
# must create a variable to store your LivestreamData class:
run1 = LivestreamData()

# now, to make the magic happen, run your variable as a function:
# note that you can select which detectors to graph
run1()
# Out:
# A Jupyter Widget
# <img src="data:image/png;base64,..." width="800">

# %%
run1.data
